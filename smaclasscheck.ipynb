# %%
from  smabacktest import SMABacktester

# %%
tester = SMABacktester("SPY",50,100,"2000-01-01","2020-01-01")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
tester.test_results()
# Out:
# (2.592726, 2.294902)

# %%
tester.plot_result()

# %%
tester = SMABacktester("GLD",50,100,"2000-01-01","2023-10-01")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
tester.test_results()
# Out:
# (2.663538, 3.996503)

# %%
tester.plot_result()

# %%
tester = SMABacktester("AAPL",1,200,"2000-01-01","2020-01-01")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
tester.test_results()
# Out:
# (239.027886, 191.213729)

# %%
tester.plot_result()

# %% [markdown]
# #### 1. Watch Stan Weistein Strategy in our youtube QuantProgram channel(2:47....)
# #### 2. Creat the strategy in python
# #### 3. Backtest it
# #### 4. Save it as a class in a separate python file.

# %%
##

# %% [markdown]
# ## API

# %% [markdown]
# #### Depending on the broker, you can find their API @ Trading APIs

# %% [markdown]
# ### Get Freee APIs at  " ALPHA VANTAGE"
# #### How to get it?? watch video from 2:53:...
